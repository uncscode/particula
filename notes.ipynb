# %%
import numpy as np
from particula import particle, rates, dynamics

# %%
p1 = particle.Particle(particle_formation_rate=0.5e15)

# %%
r1 = rates.Rates(p1)

# %%
d1 = dynamics.Solver(particle=p1, time_span=np.linspace(0, 100, 100))

# %%
x = d1.solution()

# %%
from matplotlib import pyplot as plt

# %%
plt.semilogx(p1.particle_radius.m, x[0,:].m)
plt.semilogx(p1.particle_radius.m, x[-1,:].m)

# %%
d1.nucleation_rate().m[0]
# Out:
# 500000000000000.0

# %%
plt.semilogx(p1.particle_radius.m, d1.condensation_growth_rate().m)
# plt.loglog(p1.particle_radius.m, d1.condensation_growth_speed().m)
plt.semilogx(p1.particle_radius.m, d1.nucleation_rate().m)
